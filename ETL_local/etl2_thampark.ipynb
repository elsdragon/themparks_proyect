# %%
import pandas as pd
import glob
import os
import pandas as pd

PATTERN = '*.csv'
INPUT_PATH = "/home/lucia/Documentos/themeparks/data_themeparks"
OUTPUT_FILE = "themparks_database.csv"

TIMEZONES = {
    'shanghaidisneyresort': 'Asia/Shanghai',
    'disneyland': 'America/Los_Angeles',
    'disneycaliforniaadventure': 'America/Los_Angeles',
    'waltdisneystudiosparis': 'Europe/Paris',
    'disneylandparkparis': 'Europe/Paris',
    'epcot': 'America/New_York',
    'animalkingdom': 'America/New_York',
    'disneyhollywoodstudios': 'America/New_York',
    'disneymagickingdom': 'America/New_York'
}

def extract_files(file_list):
    dfs = []

    for file in file_list:
        df = pd.read_csv(file)
        df['is_open'] = df['is_open'].replace({'False': False, 'True': True})
        df['is_open'] = df['is_open'].astype(bool)
        df['wait_time'] = pd.to_numeric(df['wait_time'], errors='coerce').fillna(0).astype(int)
        df['land_id'] = pd.to_numeric(df['land_id'], errors='coerce').fillna(0).astype(int)
        df['ride_id'] = pd.to_numeric(df['ride_id'], errors='coerce').fillna(0).astype(int)
        dfs.append(df)


    if os.path.exists(OUTPUT_FILE):
        thempark_df = pd.read_csv(OUTPUT_FILE) 
        dfs.append(thempark_df)

    return dfs

def transform(dfs):
    df = pd.concat(dfs, ignore_index=False)
    df = df.reset_index(drop=True)
    df = df.drop_duplicates()
    df['last_update'] = pd.to_datetime(df['last_update'], errors='coerce')
    df = df.dropna(subset=['last_update'])

    df= df.groupby(['last_update', 'park_name']).filter(
        lambda x: not all((x['is_open'] == False) & (x['wait_time'] == 0))
    )
    
    df = df[~df['land_name'].str.endswith('(Closed)', na=False)]
    
    df['timezone'] = df['park_name'].str.lower().map(TIMEZONES)
    
    df['last_update'] = pd.to_datetime(df['last_update'], utc=True)

    zones = df['timezone'].unique()

    dfs_processed = []

    for zone in zones:
        
        df_zone = df[df['timezone'] == zone].copy()
        
        df_zone['local_time'] = df_zone['last_update'].dt.tz_convert(zone)
     
        df_zone['local_date'] = df_zone['local_time'].dt.date
        df_zone['local_hour'] = df_zone['local_time'].dt.hour
        df_zone['local_minute'] = df_zone['local_time'].dt.minute
        df_zone['local_day_of_week'] = df_zone['local_time'].dt.dayofweek  
        df_zone['local_weekday'] = df_zone['local_time'].dt.strftime('%A')  
        
        dfs_processed.append(df_zone)

        df_final = pd.concat(dfs_processed)

    return df_final.sort_index()

# %%
file_list = glob.glob(os.path.join(INPUT_PATH, PATTERN))
dfs = extract_files(file_list)
df = transform(dfs)
df
# Out:
#        land_id       land_name  ride_id  \
# 0          779  Adventure Isle     3079
# 1          779  Adventure Isle     3893
# 2          779  Adventure Isle     2986
# 3          779  Adventure Isle     3883
# 4          779  Adventure Isle     3002
# ...        ...             ...      ...
# 71988       27     Toon Studio       34
# 71989       27     Toon Studio     7280
# 71990       27     Toon Studio       36
# 71991       27     Toon Studio       35
# 71992       27     Toon Studio     7281
#
#                                         ride_name  is_open  wait_time  \
# 0                                  Camp Discovery    False          0
# 1              Challenge Trails at Camp Discovery    False          0
# 2                                  Roaring Rapids    False          0
# 3      Selfie Spot with Disney Jungle Characters     False          0
# 4                        Soaring Over the Horizon    False          0
# ...                                           ...      ...        ...
# 71988                                    RC Racer     True         20
# 71989                       RC Racer Single Rider     True         10
# 71990                     Slinky® Dog Zigzag Spin     True          5
# 71991                 Toy Soldiers Parachute Drop    False          0
# 71992    Toy Soldiers Parachute Drop Single Rider    False          0
#
#                     last_update               park_name       timezone  \
# 0     2025-01-21 13:55:23+00:00    shanghaidisneyresort  Asia/Shanghai
# 1     2025-01-21 13:55:23+00:00    shanghaidisneyresort  Asia/Shanghai
# 2     2025-01-21 13:55:23+00:00    shanghaidisneyresort  Asia/Shanghai
# 3     2025-01-21 13:55:23+00:00    shanghaidisneyresort  Asia/Shanghai
# 4     2025-01-21 13:55:23+00:00    shanghaidisneyresort  Asia/Shanghai
# ...                         ...                     ...            ...
# 71988 2025-01-24 17:55:05+00:00  waltdisneystudiosparis   Europe/Paris
# 71989 2025-01-24 17:55:05+00:00  waltdisneystudiosparis   Europe/Paris
# 71990 2025-01-24 17:55:05+00:00  waltdisneystudiosparis   Europe/Paris
# 71991 2025-01-24 17:55:05+00:00  waltdisneystudiosparis   Europe/Paris
# 71992 2025-01-24 17:55:05+00:00  waltdisneystudiosparis   Europe/Paris
#
#                       local_time  local_date  local_hour  local_minute  \
# 0      2025-01-21 21:55:23+08:00  2025-01-21          21            55
# 1      2025-01-21 21:55:23+08:00  2025-01-21          21            55
# 2      2025-01-21 21:55:23+08:00  2025-01-21          21            55
# 3      2025-01-21 21:55:23+08:00  2025-01-21          21            55
# 4      2025-01-21 21:55:23+08:00  2025-01-21          21            55
# ...                          ...         ...         ...           ...
# 71988  2025-01-24 18:55:05+01:00  2025-01-24          18            55
# 71989  2025-01-24 18:55:05+01:00  2025-01-24          18            55
# 71990  2025-01-24 18:55:05+01:00  2025-01-24          18            55
# 71991  2025-01-24 18:55:05+01:00  2025-01-24          18            55
# 71992  2025-01-24 18:55:05+01:00  2025-01-24          18            55
#
#        local_day_of_week local_weekday
# 0                      1       Tuesday
# 1                      1       Tuesday
# 2                      1       Tuesday
# 3                      1       Tuesday
# 4                      1       Tuesday
# ...                  ...           ...
# 71988                  4        Friday
# 71989                  4        Friday
# 71990                  4        Friday
# 71991                  4        Friday
# 71992                  4        Friday
#
# [61848 rows x 15 columns]

# %%
parques = list(df['park_name'].unique())
parques
# Out:
# ['shanghaidisneyresort',
#  'waltdisneystudiosparis',
#  'disneylandparkparis',
#  'epcot',
#  'animalkingdom',
#  'disneycaliforniaadventure',
#  'disneymagickingdom',
#  'disneyhollywoodstudios',
#  'disneyland']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61848 entries, 0 to 71992
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   land_id            61848 non-null  int64
#  1   land_name          61848 non-null  object
#  2   ride_id            61848 non-null  int64
#  3   ride_name          61848 non-null  object
#  4   is_open            61848 non-null  bool
#  5   wait_time          61848 non-null  int64
#  6   last_update        61848 non-null  datetime64[ns, UTC]
#  7   park_name          61848 non-null  object
#  8   timezone           61848 non-null  object
#  9   local_time         61848 non-null  object
#  10  local_date         61848 non-null  object
#  11  local_hour         61848 non-null  int32
#  12  local_minute       61848 non-null  int32
#  13  local_day_of_week  61848 non-null  int32
#  14  local_weekday      61848 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), int32(3), int64(3), object(7)
# memory usage: 6.4+ MB
